# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from prophet import Prophet
import seaborn as sns 
import datetime
# %matplotlib inline

# %%
#  Import and read the cash_data.csv.
import pandas as pd 
cash_df = pd.read_csv("LB_Forecast_Cash.csv")
cash_df.head()
# Out:
#    Year  Week       Date        Cash  Recievables
# 0  2022     1   1/3/2022  1347046.53    216637.49
# 1  2022     2  1/10/2022  1348547.51    220001.93
# 2  2022     3  1/17/2022  1362682.96    186053.69
# 3  2022     4  1/24/2022  1297296.15    291930.41
# 4  2022     5  1/31/2022  1328902.74    298268.57

# %%
# Drop the non-beneficial ID columns, 'Year'.
cash_df.drop(['Year'], axis=1, inplace=True)

# %%
# Determine the number of unique values in each column.
cash_df.nunique()
# Out:
# Week           50
# Date           50
# Cash           50
# Recievables    45
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
cash_type_counts = cash_df['Cash'].value_counts()
cash_type_counts
# Out:
# 1347046.53    1
# 1190238.49    1
# 1304364.28    1
# 1261909.63    1
# 1236691.88    1
# 1014785.56    1
# 1133650.37    1
# 1161283.97    1
# 1128302.52    1
# 1123132.28    1
# 1124330.80    1
# 1160669.15    1
# 1214039.45    1
# 1348547.51    1
# 1241409.75    1
# 1255707.57    1
# 1238016.13    1
# 1167949.74    1
# 1179447.65    1
# 1206666.30    1
# 1342166.25    1
# 1349235.80    1
# 1364913.41    1
# 1408474.30    1
# 1237273.42    1
# 1307593.21    1
# 1346230.42    1
# 1431530.95    1
# 1362682.96    1
# 1297296.15    1
# 1328902.74    1
# 1323508.00    1
# 1303868.81    1
# 1305221.38    1
# 1299636.89    1
# 1286504.39    1
# 1311554.52    1
# 1468436.95    1
# 1462666.44    1
# 1430839.10    1
# 1405144.19    1
# 1355927.76    1
# 1460328.96    1
# 1517710.38    1
# 1517876.59    1
# 1392393.04    1
# 1367283.46    1
# 1547313.41    1
# 1487014.83    1
# 1404733.85    1
# Name: Cash, dtype: int64

# %%
cash_df.isnull().sum()
# Out:
# Week           0
# Date           0
# Cash           0
# Recievables    0
# dtype: int64

# %%
x = cash_df[['Cash']]
y = cash_df['Recievables']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
plt.scatter(x_train['Cash'], y_train, s=10)
plt.title('Cash vs Recievables')
plt.xlabel ('Cash')
plt.ylabel ('Recievables')
# Out:
# Text(0, 0.5, 'Recievables')

# %%
lr = LinearRegression()
lr.fit (x_train, y_train)
# Out:
# LinearRegression()

# %%
print (lr.intercept_)
print (lr.coef_)
# Out:
# 229132.83827108316
# [0.09606524]

# %%
plt.scatter(x_train['Cash'], y_train, s=10)
y_pred = lr.predict(x_train)
plt.plot(x_train['Cash'], y_pred)

plt.title('Cash vs Recievables')
plt.xlabel('Cash')
plt.ylabel ('Recievables')
# Out:
# Text(0, 0.5, 'Recievables')

# %%
RMSE = mean_squared_error(y_train, y_pred, squared=False)
r2 = r2_score(y_train, y_pred)
print(RMSE)
print(r2)
# Out:
# 121040.92031357488
# 0.00775152375407695

# %%
y_pred_test = lr.predict(x_test)
RMSE =  mean_squared_error (y_test, y_pred_test, squared=False)
r2 = r2_score(y_test, y_pred_test)
print(RMSE)
print(r2)
# Out:
# 83013.6165149443
# -0.3090407617535367

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features =  PolynomialFeatures (degree=2)
x_train_transformed = poly_features.fit_transform(x_train)

# %%
print(x_train_transformed[0])
# Out:
# [1.00000000e+00 1.46266644e+06 2.13939311e+12]

# %%
pr = LinearRegression()
pr.fit(x_train_transformed,y_train)
print(pr.intercept_)
print(pr.coef_)
# Out:
# 1631706.9054997866
# [ 0.00000000e+00 -2.05173899e+00  8.16343392e-07]

# %%
#Plotting the scatter plot
plt.scatter(x_train['Cash'], y_train, s=10)

# %%
#Plotting the scatter plot
plt.scatter(x_train['Cash'], y_train, s=10)


#Plotting the curve
y_pred = pr.predict(x_train_transformed)
sorted_zip = sorted(zip(x_train['Cash'], y_pred))
x_train_sorted, y_pred_sorted = zip(*sorted_zip)
plt.plot(x_train_sorted, y_pred_sorted)

plt.title('Cash vs Receivables')
plt.xlabel('Cash')
plt.ylabel('Receivables')
# Out:
# Text(0, 0.5, 'Receivables')

# %%
def plot_cash_df(cash_df, x, y, title="", xlabel='Week', ylabel='Cash', dpi=100):
    plt.figure(figsize=(15,4), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
    

plot_cash_df(cash_df, x=cash_df['Week'], y=cash_df['Cash'], title='Cash Forecast')

# %%
x = cash_df['Week'].values
y1 = cash_df['Cash'].values

# Plot
fig, ax = plt.subplots(1, 1, figsize=(16,5), dpi= 120)
plt.fill_between(x, y1=y1, y2=-y1, alpha=0.5, linewidth=2, color='seagreen')
plt.ylim(-1500000, 1500000)
plt.title('Cash Forecast (Two Side View)', fontsize=16)
plt.hlines(y=0, xmin=np.min(cash_df['Week']), xmax=np.max(cash_df['Week']), linewidth=.5)
plt.show()

# %%
def plot_cash_df(cash_df, x, y, title="", xlabel='Week', ylabel='Cash', dpi=100):
    plt.figure(figsize=(15,4), dpi=dpi)
    plt.plot(x, y, color='blue')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
    

plot_cash_df(cash_df, x=cash_df['Week'], y=cash_df['Cash'], title='Cash Forecast')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# %%
# Multiplicative Decomposition 
multiplicative_decomposition = seasonal_decompose(cash_df['Cash'], model='multiplicative', period=25)

# Additive Decomposition
additive_decomposition = seasonal_decompose(cash_df['Cash'], model='additive', period=25)

# Plot
plt.rcParams.update({'figure.figsize': (16,12)})
multiplicative_decomposition.plot().suptitle('Multiplicative Decomposition', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

additive_decomposition.plot().suptitle('Additive Decomposition', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()

# %%
#Split Train Test
import math
total_size=len(cash_df)
split = 10392 / 11856
train_size=math.floor(split*total_size)
train=cash_df.head(train_size)
test=cash_df.tail(len(cash_df) -train_size)

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
# Create prediction table
y_hat = test.copy()
fit2 = SimpleExpSmoothing(np.asarray(train['Cash'])).fit(smoothing_level=0.6,optimized=False)
y_hat['SES'] = fit2.forecast(len(test))

# %%
#Plotting data
plt.figure(figsize=(12,8))
plt.plot(train.index, train['Cash'], label='Train')
plt.plot(test.index,test['Cash'], label='Test')
plt.plot(y_hat.index,y_hat['SES'], label='SES')
plt.legend(loc='best')
plt.title("Simple Exponential Smoothing (SES)")
plt.show()

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# using single exponential smoothing

cash_df.index # freq None is not allowed for these computations
cash_df.index.freq = 'MS'
cash_df.index

span=12
alpha=2/(span+1)
model = SimpleExpSmoothing(cash_df['Cash'])
fit_model = model.fit(smoothing_level=alpha, 
                      optimized=False)
cash_df['ses'] = fit_model.fittedvalues.shift(-1)
cash_df.plot(figsize=(14, 8))
# Out:
# <AxesSubplot:>

# %%
#Double Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

fit_mod = ExponentialSmoothing(cash_df['Cash'], 
                               trend='add').fit()
cash_df['predicted'] = fit_mod.fittedvalues.shift(-1)
cash_df[['Cash', 'predicted']].iloc[:24].plot(figsize=(16,8))
# Out:
# C:\Users\User\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# <AxesSubplot:>

# %%
#Making predictions with ARIMA

# %%
p_df = pd.read_csv('LB_Forecast_Cash.csv', 
                   index_col='Week', 
                   parse_dates= True)
from statsmodels.tsa.arima_model import ARIMA, ARMA, ARIMAResults, ARMAResults
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima

p_df.plot(figsize=(16,8))

# auto_arima(p_df, seasonal=True, trace=True).summary()

# ARIMA(2, 0, 2)
p_df.size # 480
train_cash_df = p_df.iloc[:384]
test_cash_df = p_df.iloc[384:]
mod = ARIMA(train_cash_df, order=(2,0,2))
res = mod.fit()
# res.summary()

start = len(train_cash_df)
end = len(train_cash_df) + len(test_cash_df) - 1
prediction = res.predict(start, end).rename('ARIMA Prediction')
p_df.plot(figsize=(16,8), legend = True)
prediction.plot(legend=True)
p_df.index
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13724\3989622993.py in <module>
#      14 train_cash_df = p_df.iloc[:384]
#      15 test_cash_df = p_df.iloc[384:]
# ---> 16 mod = ARIMA(train_cash_df, order=(2,0,2))
#      17 res = mod.fit()
#      18 # res.summary()
#
# ~\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# ~\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
#Building the Decision Tree Model on our dataset
from sklearn.tree import DecisionTreeRegressor
DT_model = DecisionTreeRegressor(max_depth=5).fit(x_train,y_train)
DT_predict = DT_model.predict(x_test) #Predictions on Testing data
print(DT_predict)
# Out:
# [325171.09666667 283963.895      415927.57       312881.19
#  414849.50666667 411109.15       215610.15       469080.88
#  313597.976      411109.15      ]

# %%
#Building the KNN Model on our dataset
from sklearn.neighbors import KNeighborsRegressor
KNN_model = KNeighborsRegressor(n_neighbors=3).fit(x_train,y_train)
KNN_predict = KNN_model.predict(x_test) #Predictions on Testing data
print(KNN_predict)
# Out:
# [332698.28333333 261179.31333333 408301.36666667 254711.07666667
#  414849.50666667 332698.28333333 261179.31333333 471699.01666667
#  315330.15       411109.15      ]
# C:\Users\User\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\sklearn\base.py:442: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   "X does not have valid feature names, but"

# %%
# Python
cash_df_1 = pd.read_csv('LB_Forecast_Cash_1.csv')
cash_df_1.head()
# Out:
#    Year  Week         ds           y  Recievables
# 0  2022     1   1/3/2022  1347046.53    216637.49
# 1  2022     2  1/10/2022  1348547.51    220001.93
# 2  2022     3  1/17/2022  1362682.96    186053.69
# 3  2022     4  1/24/2022  1297296.15    291930.41
# 4  2022     5  1/31/2022  1328902.74    298268.57

# %%
# convert the 'Date' column to datetime format
cash_df_1['ds'] = cash_df_1['ds'].astype('datetime64[ns]')

# %%
# Check the format of 'Date' column
cash_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         50 non-null     int64
#  1   Week         50 non-null     int64
#  2   ds           50 non-null     datetime64[ns]
#  3   y            50 non-null     float64
#  4   Recievables  50 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 2.1 KB

# %%
# Python
m = Prophet()
m.fit(cash_df_1)
# Out:
# 21:38:19 - cmdstanpy - INFO - Chain [1] start processing
# 21:38:20 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Python
future = m.make_future_dataframe(periods=52)
future.tail()
# Out:
#             ds
# 97  2023-01-29
# 98  2023-01-30
# 99  2023-01-31
# 100 2023-02-01
# 101 2023-02-02

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 97  2023-01-29  1.210646e+06  1.062844e+06  1.352492e+06
# 98  2023-01-30  1.210197e+06  1.056970e+06  1.342363e+06
# 99  2023-01-31  1.209749e+06  1.074336e+06  1.347010e+06
# 100 2023-02-01  1.209300e+06  1.073992e+06  1.345846e+06
# 101 2023-02-02  1.208851e+06  1.066009e+06  1.351708e+06

# %%
# Python
fig1 = m.plot(forecast)

# %%
# Python
fig2 = m.plot_components(forecast)

# %%
# Python
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# <div>                            <div id="0e77d08b-a16a-459b-b2ea-fcc17c8323fa" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e77d08b-a16a-459b-b2ea-fcc17c8323fa")) {                    Plotly.newPlot(                        "0e77d08b-a16a-459b-b2ea-fcc17c8323fa",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2022-01-03T00:00:00","2022-01-10T00:00:00","2022-01-17T00:00:00","2022-01-24T00:00:00","2022-01-31T00:00:00","2022-02-07T00:00:00","2022-02-14T00:00:00","2022-02-21T00:00:00","2022-02-28T00:00:00","2022-03-07T00:00:00","2022-03-14T00:00:00","2022-03-21T00:00:00","2022-03-28T00:00:00","2022-04-04T00:00:00","2022-04-11T00:00:00","2022-04-18T00:00:00","2022-04-25T00:00:00","2022-05-02T00:00:00","2022-05-09T00:00:00","2022-05-16T00:00:00","2022-05-23T00:00:00","2022-05-30T00:00:00","2022-06-06T00:00:00","2022-06-13T00:00:00","2022-06-20T00:00:00","2022-06-27T00:00:00","2022-07-04T00:00:00","2022-07-11T00:00:00","2022-07-18T00:00:00","2022-07-25T00:00:00","2022-08-01T00:00:00","2022-08-08T00:00:00","2022-08-15T00:00:00","2022-08-22T00:00:00","2022-08-29T00:00:00","2022-09-05T00:00:00","2022-09-12T00:00:00","2022-09-19T00:00:00","2022-09-26T00:00:00","2022-10-03T00:00:00","2022-10-10T00:00:00","2022-10-17T00:00:00","2022-10-24T00:00:00","2022-10-31T00:00:00","2022-11-07T00:00:00","2022-11-14T00:00:00","2022-11-21T00:00:00","2022-11-28T00:00:00","2022-12-05T00:00:00","2022-12-12T00:00:00"],"y":[1347046.53,1348547.51,1362682.96,1297296.15,1328902.74,1323508.0,1303868.81,1305221.38,1299636.89,1286504.39,1311554.52,1468436.95,1462666.44,1430839.1,1405144.19,1355927.76,1460328.96,1517710.38,1517876.59,1392393.04,1367283.46,1547313.41,1487014.83,1431530.95,1346230.42,1307593.21,1237273.42,1304364.28,1261909.63,1236691.88,1014785.56,1133650.37,1161283.97,1128302.52,1123132.28,1124330.8,1160669.15,1190238.49,1214039.45,1241409.75,1255707.57,1238016.13,1167949.74,1179447.65,1206666.3,1342166.25,1349235.8,1364913.41,1408474.3,1404733.85],"type":"scatter"},{"hoverinfo":"skip","line":{"width":0},"mode":"lines","x":["2022-01-03T00:00:00","2022-01-10T00:00:00","2022-01-17T00:00:00","2022-01-24T00:00:00","2022-01-31T00:00:00","2022-02-07T00:00:00","2022-02-14T00:00:00","2022-02-21T00:00:00","2022-02-28T00:00:00","2022-03-07T00:00:00","2022-03-14T00:00:00","2022-03-21T00:00:00","2022-03-28T00:00:00","2022-04-04T00:00:00","2022-04-11T00:00:00","2022-04-18T00:00:00","2022-04-25T00:00:00","2022-05-02T00:00:00","2022-05-09T00:00:00","2022-05-16T00:00:00","2022-05-23T00:00:00","2022-05-30T00:00:00","2022-06-06T00:00:00","2022-06-13T00:00:00","2022-06-20T00:00:00","2022-06-27T00:00:00","2022-07-04T00:00:00","2022-07-11T00:00:00","2022-07-18T00:00:00","2022-07-25T00:00:00","2022-08-01T00:00:00","2022-08-08T00:00:00","2022-08-15T00:00:00","2022-08-22T00:00:00","2022-08-29T00:00:00","2022-09-05T00:00:00","2022-09-12T00:00:00","2022-09-19T00:00:00","2022-09-26T00:00:00","2022-10-03T00:00:00","2022-10-10T00:00:00","2022-10-17T00:00:00","2022-10-24T00:00:00","2022-10-31T00:00:00","2022-11-07T00:00:00","2022-11-14T00:00:00","2022-11-21T00:00:00","2022-11-28T00:00:00","2022-12-05T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00: ...

# %%
# Python
plot_components_plotly(m, forecast)
# Out:
# <div>                            <div id="5d96bb74-6630-4147-a63c-f724473b1e2b" class="plotly-graph-div" style="height:200px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d96bb74-6630-4147-a63c-f724473b1e2b")) {                    Plotly.newPlot(                        "5d96bb74-6630-4147-a63c-f724473b1e2b",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2022-01-03T00:00:00","2022-01-10T00:00:00","2022-01-17T00:00:00","2022-01-24T00:00:00","2022-01-31T00:00:00","2022-02-07T00:00:00","2022-02-14T00:00:00","2022-02-21T00:00:00","2022-02-28T00:00:00","2022-03-07T00:00:00","2022-03-14T00:00:00","2022-03-21T00:00:00","2022-03-28T00:00:00","2022-04-04T00:00:00","2022-04-11T00:00:00","2022-04-18T00:00:00","2022-04-25T00:00:00","2022-05-02T00:00:00","2022-05-09T00:00:00","2022-05-16T00:00:00","2022-05-23T00:00:00","2022-05-30T00:00:00","2022-06-06T00:00:00","2022-06-13T00:00:00","2022-06-20T00:00:00","2022-06-27T00:00:00","2022-07-04T00:00:00","2022-07-11T00:00:00","2022-07-18T00:00:00","2022-07-25T00:00:00","2022-08-01T00:00:00","2022-08-08T00:00:00","2022-08-15T00:00:00","2022-08-22T00:00:00","2022-08-29T00:00:00","2022-09-05T00:00:00","2022-09-12T00:00:00","2022-09-19T00:00:00","2022-09-26T00:00:00","2022-10-03T00:00:00","2022-10-10T00:00:00","2022-10-17T00:00:00","2022-10-24T00:00:00","2022-10-31T00:00:00","2022-11-07T00:00:00","2022-11-14T00:00:00","2022-11-21T00:00:00","2022-11-28T00:00:00","2022-12-05T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-14T00:00:00","2023-01-15T00:00:00","2023-01-16T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-21T00:00:00","2023-01-22T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-26T00:00:00","2023-01-27T00:00:00","2023-01-28T00:00:00","2023-01-29T00:00:00","2023-01-30T00:00:00","2023-01-31T00:00:00","2023-02-01T00:00:00","2023-02-02T00:00:00"],"y":[1386381.98416613,1383232.8224428836,1380083.6607196373,1376934.4989670005,1373785.3371980628,1370636.175429125,1367487.0136435684,1364337.8518220647,1361188.6900005608,1358039.528201635,1354890.3663431488,1351741.2044846625,1348592.0425614736,1345442.8795486605,1342293.7165358476,1339144.5268565721,1335995.3371772964,1332846.130677019,1329696.9241714363,1326547.717665854,1323398.2495531512,1320248.7813781297,1317099.3132031083,1313949.8449768173,1310800.376742391,1307650.9085079643,1304501.4402283125,1301351.9719486604,1298202.5036749002,1295053.0373657353,1291903.5710565706,1288754.3178519346,1285605.2220725438,1282456.1262931533,1279307.9033658884,1276163.4184004657,1273018.9334350433,1269877.2236899016,1266735.7393848505,1263594.255079799,1260453.2672949901,1257312.279510181,1254171.291725372,1251030.3039405628,1247889.3161557538,1244748.3283709446,1241607.3405861354,1238466.3528013264,1235325.3650165175,1232184.3772317083,1231735.6646910212,1231286.9521503341,1230838.2396096473,1230389.5270689602,1229940.8145282732,1229492.1019875861,1229043.389446899,1228594.676906212,1228145.9643655252,1227697.251824838,1227248.539284151, ...

# %%
# Python
rec_df_1 = pd.read_csv('LB_Forecast_Rec_1.csv')
rec_df_1.head()
# Out:
#    Year  Week         ds          y
# 0  2022     1   1/3/2022  216637.49
# 1  2022     2  1/10/2022  220001.93
# 2  2022     3  1/17/2022  186053.69
# 3  2022     4  1/24/2022  291930.41
# 4  2022     5  1/31/2022  298268.57

# %%
# convert the 'Date' column to datetime format
rec_df_1['ds'] = rec_df_1['ds'].astype('datetime64[ns]')

# %%
# Check the format of 'Date' column
rec_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    50 non-null     int64
#  1   Week    50 non-null     int64
#  2   ds      50 non-null     datetime64[ns]
#  3   y       50 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 1.7 KB

# %%
# Python
m = Prophet()
m.fit(rec_df_1)
# Out:
# 21:07:58 - cmdstanpy - INFO - Chain [1] start processing
# 21:07:59 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Python
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 410 2023-12-08
# 411 2023-12-09
# 412 2023-12-10
# 413 2023-12-11
# 414 2023-12-12

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds           yhat    yhat_lower     yhat_upper
# 410 2023-12-08  111907.100550 -23544.280640  242456.624464
# 411 2023-12-09  111465.535925 -25396.601385  242478.606677
# 412 2023-12-10  111023.971300 -22715.723123  253886.636213
# 413 2023-12-11  110582.406675 -24103.793661  245656.828684
# 414 2023-12-12  110140.842050 -26478.734509  239365.802592

# %%
# Python
fig1 = m.plot(forecast)

# %%
# Python
fig2 = m.plot_components(forecast)

# %%
# Python
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# <div>                            <div id="b65e9e4c-b26a-497f-8098-84a649cf23f5" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b65e9e4c-b26a-497f-8098-84a649cf23f5")) {                    Plotly.newPlot(                        "b65e9e4c-b26a-497f-8098-84a649cf23f5",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2022-01-03T00:00:00","2022-01-10T00:00:00","2022-01-17T00:00:00","2022-01-24T00:00:00","2022-01-31T00:00:00","2022-02-07T00:00:00","2022-02-14T00:00:00","2022-02-21T00:00:00","2022-02-28T00:00:00","2022-03-07T00:00:00","2022-03-14T00:00:00","2022-03-21T00:00:00","2022-03-28T00:00:00","2022-04-04T00:00:00","2022-04-11T00:00:00","2022-04-18T00:00:00","2022-04-25T00:00:00","2022-05-02T00:00:00","2022-05-09T00:00:00","2022-05-16T00:00:00","2022-05-23T00:00:00","2022-05-30T00:00:00","2022-06-06T00:00:00","2022-06-13T00:00:00","2022-06-20T00:00:00","2022-06-27T00:00:00","2022-07-04T00:00:00","2022-07-11T00:00:00","2022-07-18T00:00:00","2022-07-25T00:00:00","2022-08-01T00:00:00","2022-08-08T00:00:00","2022-08-15T00:00:00","2022-08-22T00:00:00","2022-08-29T00:00:00","2022-09-05T00:00:00","2022-09-12T00:00:00","2022-09-19T00:00:00","2022-09-26T00:00:00","2022-10-03T00:00:00","2022-10-10T00:00:00","2022-10-17T00:00:00","2022-10-24T00:00:00","2022-10-31T00:00:00","2022-11-07T00:00:00","2022-11-14T00:00:00","2022-11-21T00:00:00","2022-11-28T00:00:00","2022-12-05T00:00:00","2022-12-12T00:00:00"],"y":[216637.49,220001.93,186053.69,291930.41,298268.57,398634.08,580196.23,580196.23,586159.15,674885.53,572341.82,456806.39,354358.83,408124.82,434353.17,354264.8,404625.08,197243.99,451761.98,451761.98,451761.98,396393.27,396393.27,216529.38,327493.81,327493.81,308396.11,254704.59,228934.24,215610.15,288174.84,321982.83,347062.66,421901.72,415927.57,387074.81,330464.26,300016.6,348915.85,285427.63,279353.31,288574.48,298545.01,316981.18,222145.96,222773.09,206623.94,164934.77,324207.63,337199.6],"type":"scatter"},{"hoverinfo":"skip","line":{"width":0},"mode":"lines","x":["2022-01-03T00:00:00","2022-01-10T00:00:00","2022-01-17T00:00:00","2022-01-24T00:00:00","2022-01-31T00:00:00","2022-02-07T00:00:00","2022-02-14T00:00:00","2022-02-21T00:00:00","2022-02-28T00:00:00","2022-03-07T00:00:00","2022-03-14T00:00:00","2022-03-21T00:00:00","2022-03-28T00:00:00","2022-04-04T00:00:00","2022-04-11T00:00:00","2022-04-18T00:00:00","2022-04-25T00:00:00","2022-05-02T00:00:00","2022-05-09T00:00:00","2022-05-16T00:00:00","2022-05-23T00:00:00","2022-05-30T00:00:00","2022-06-06T00:00:00","2022-06-13T00:00:00","2022-06-20T00:00:00","2022-06-27T00:00:00","2022-07-04T00:00:00","2022-07-11T00:00:00","2022-07-18T00:00:00","2022-07-25T00:00:00","2022-08-01T00:00:00","2022-08-08T00:00:00","2022-08-15T00:00:00","2022-08-22T00:00:00","2022-08-29T00:00:00","2022-09-05T00:00:00","2022-09-12T00:00:00","2022-09-19T00:00:00","2022-09-26T00:00:00","2022-10-03T00:00:00","2022-10-10T00:00:00","2022-10-17T00:00:00","2022-10-24T00:00:00","2022-10-31T00:00:00","2022-11-07T00:00:00","2022-11-14T00:00:00","2022-11-21T00:00:00","2022-11-28T00:00:00","2022-12-05T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00: ...

# %%
# Python
plot_components_plotly(m, forecast)
# Out:
# <div>                            <div id="ddf3d47a-a1fb-4c97-9b28-92acd672b9a9" class="plotly-graph-div" style="height:200px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddf3d47a-a1fb-4c97-9b28-92acd672b9a9")) {                    Plotly.newPlot(                        "ddf3d47a-a1fb-4c97-9b28-92acd672b9a9",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2022-01-03T00:00:00","2022-01-10T00:00:00","2022-01-17T00:00:00","2022-01-24T00:00:00","2022-01-31T00:00:00","2022-02-07T00:00:00","2022-02-14T00:00:00","2022-02-21T00:00:00","2022-02-28T00:00:00","2022-03-07T00:00:00","2022-03-14T00:00:00","2022-03-21T00:00:00","2022-03-28T00:00:00","2022-04-04T00:00:00","2022-04-11T00:00:00","2022-04-18T00:00:00","2022-04-25T00:00:00","2022-05-02T00:00:00","2022-05-09T00:00:00","2022-05-16T00:00:00","2022-05-23T00:00:00","2022-05-30T00:00:00","2022-06-06T00:00:00","2022-06-13T00:00:00","2022-06-20T00:00:00","2022-06-27T00:00:00","2022-07-04T00:00:00","2022-07-11T00:00:00","2022-07-18T00:00:00","2022-07-25T00:00:00","2022-08-01T00:00:00","2022-08-08T00:00:00","2022-08-15T00:00:00","2022-08-22T00:00:00","2022-08-29T00:00:00","2022-09-05T00:00:00","2022-09-12T00:00:00","2022-09-19T00:00:00","2022-09-26T00:00:00","2022-10-03T00:00:00","2022-10-10T00:00:00","2022-10-17T00:00:00","2022-10-24T00:00:00","2022-10-31T00:00:00","2022-11-07T00:00:00","2022-11-14T00:00:00","2022-11-21T00:00:00","2022-11-28T00:00:00","2022-12-05T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-14T00:00:00","2023-01-15T00:00:00","2023-01-16T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-21T00:00:00","2023-01-22T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-26T00:00:00","2023-01-27T00:00:00","2023-01-28T00:00:00","2023-01-29T00:00:00","2023-01-30T00:00:00","2023-01-31T00:00:00","2023-02-01T00:00:00","2023-02-02T00:00:00","2023-02-03T00:00:00","2023-02-04T00:00:00","2023-02-05T00:00:00","2023-02-06T00:00:00","2023-02-07T00:00:00","2023-02-08T00:00:00","2023-02-09T00:00:00","2023-02-10T00:00:00","2023-02-11T00:00:00","2023-02-12T00:00:00","2023-02-13T00:00:00","2023-02-14T00:00:00","2023-02-15T00:00:00","2023-02-16T00:00:00","2023-02-17T00:00:00","2023-02-18T00:00:00","2023-02-19T00:00:00","2023-02-20T00:00:00","2023-02-21T00:00:00","2023-02-22T00:00:00","2023-02-23T00:00:00","2023-02-24T00:00:00","2023-02-25T00:00:00","2023-02-26T00:00:00","2023-02-27T00:00:00","2023-02-28T00:00:00","2023-03-01T00:00:00","2023-03-02T00:00:00","2023-03-03T00:00:00","2023-03-04T00:00:00","2023-03-05T00:00:00","2023-03-06T00:00:00","2023-03-07T00:00:00","2023-03-08T00:00:00","2023-03-09T00:00:00","2023-03-10T00:00:00","2023-03-11T00:00:00","2023-03-12T00:00:00","2023-03-13T00:00:00","2023-03-14T00:00:00","2023-03-15T00:00:00","2023-03-16T00:00:00","2023-03-17T00:00:00","2023-03-18T00:00:00","2023-03-19T00:00:00","2023-03-20T00:00:00","2023-03-21T00:00:00","2023-03-22T00:00:00","2023-03-23T00:00:00","2023-03-24T00:00:00","2023-03-25T00:00:00","2023-03-26T00:00:00","2023-0 ...

# %%
# Python
sales_df = pd.read_csv('LB_Sales.csv')
sales_df.head()
# Out:
#          ds        y
# 0  1/1/2022  9942.12
# 1  1/3/2022  2096.89
# 2  1/3/2022   846.37
# 3  1/3/2022   390.00
# 4  1/3/2022   657.65

# %%
# convert the 'Date' column to datetime format
sales_df['ds'] = sales_df['ds'].astype('datetime64[ns]')

# %%
# Check the format of 'Date' column
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      615 non-null    datetime64[ns]
#  1   y       614 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 9.7 KB

# %%
# Python
m = Prophet()
m.fit(sales_df)
# Out:
# 21:08:08 - cmdstanpy - INFO - Chain [1] start processing
# 21:08:09 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Python
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#             ds
# 431 2023-11-28
# 432 2023-11-29
# 433 2023-11-30
# 434 2023-12-01
# 435 2023-12-02

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds         yhat    yhat_lower    yhat_upper
# 431 2023-11-28 -1836.410857 -16913.644100  13443.088869
# 432 2023-11-29  -492.194749 -16559.325492  15678.846401
# 433 2023-11-30  -419.411288 -16533.524270  15701.155930
# 434 2023-12-01  -889.797873 -16851.515902  15887.657899
# 435 2023-12-02  1835.895773 -14401.676728  18478.461484

# %%
# Python
fig1 = m.plot(forecast)

# %%
# Python
fig2 = m.plot_components(forecast)

# %%
# Python
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# <div>                            <div id="ecd6a9b0-65a8-4a92-9942-9ccab1cf631d" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ecd6a9b0-65a8-4a92-9942-9ccab1cf631d")) {                    Plotly.newPlot(                        "ecd6a9b0-65a8-4a92-9942-9ccab1cf631d",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2022-01-01T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-04T00:00:00","2022-01-04T00:00:00","2022-01-04T00:00:00","2022-01-04T00:00:00","2022-01-04T00:00:00","2022-01-04T00:00:00","2022-01-04T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-05T00:00:00","2022-01-05T00:00:00","2022-01-05T00:00:00","2022-01-05T00:00:00","2022-01-05T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-06T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-12T00:00:00","2022-01-12T00:00:00","2022-01-12T00:00:00","2022-01-12T00:00:00","2022-01-12T00:00:00","2022-01-12T00:00:00","2022-01-12T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-19T00:00:00","2022-01-21T00:00:00","2022-01-25T00:00:00","2022-01-25T00:00:00","2022-01-25T00:00:00","2022-01-25T00:00:00","2022-01-25T00:00:00","2022-01-25T00:00:00","2022-01-25T00:00:00","2022-02-01T00:00:00","2022-02-01T00:00:00","2022-02-01T00:00:00","2022-02-01T00:00:00","2022-02-01T00:00:00","2022-02-01T00:00:00","2022-02-01T00:00:00","2022-02-01T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-02T00:00:00","2022-02-02T00:00:00","2022-02-02T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-10T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-23T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-02-25T00:00:00","2022-03-05T00:00:00","2022 ...

# %%
# Python
plot_components_plotly(m, forecast)
# Out:
# <div>                            <div id="d6be7719-1b53-4b86-87a9-ddc33488a1aa" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6be7719-1b53-4b86-87a9-ddc33488a1aa")) {                    Plotly.newPlot(                        "d6be7719-1b53-4b86-87a9-ddc33488a1aa",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2022-01-01T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-12T00:00:00","2022-01-19T00:00:00","2022-01-21T00:00:00","2022-01-25T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-10T00:00:00","2022-02-17T00:00:00","2022-02-23T00:00:00","2022-02-25T00:00:00","2022-03-05T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-15T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-25T00:00:00","2022-04-15T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-05-03T00:00:00","2022-05-06T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-20T00:00:00","2022-05-27T00:00:00","2022-06-02T00:00:00","2022-06-13T00:00:00","2022-06-16T00:00:00","2022-06-29T00:00:00","2022-07-07T00:00:00","2022-07-12T00:00:00","2022-07-13T00:00:00","2022-07-14T00:00:00","2022-07-15T00:00:00","2022-07-18T00:00:00","2022-07-25T00:00:00","2022-07-27T00:00:00","2022-07-28T00:00:00","2022-08-04T00:00:00","2022-08-05T00:00:00","2022-08-08T00:00:00","2022-08-11T00:00:00","2022-08-16T00:00:00","2022-08-17T00:00:00","2022-08-19T00:00:00","2022-08-20T00:00:00","2022-08-26T00:00:00","2022-09-01T00:00:00","2022-09-07T00:00:00","2022-09-08T00:00:00","2022-09-13T00:00:00","2022-09-21T00:00:00","2022-09-28T00:00:00","2022-09-30T00:00:00","2022-10-07T00:00:00","2022-10-19T00:00:00","2022-10-20T00:00:00","2022-10-26T00:00:00","2022-11-04T00:00:00","2022-11-16T00:00:00","2022-12-02T00:00:00","2022-12-03T00:00:00","2022-12-04T00:00:00","2022-12-05T00:00:00","2022-12-06T00:00:00","2022-12-07T00:00:00","2022-12-08T00:00:00","2022-12-09T00:00:00","2022-12-10T00:00:00","2022-12-11T00:00:00","2022-12-12T00:00:00","2022-12-13T00:00:00","2022-12-14T00:00:00","2022-12-15T00:00:00","2022-12-16T00:00:00","2022-12-17T00:00:00","2022-12-18T00:00:00","2022-12-19T00:00:00","2022-12-20T00:00:00","2022-12-21T00:00:00","2022-12-22T00:00:00","2022-12-23T00:00:00","2022-12-24T00:00:00","2022-12-25T00:00:00","2022-12-26T00:00:00","2022-12-27T00:00:00","2022-12-28T00:00:00","2022-12-29T00:00:00","2022-12-30T00:00:00","2022-12-31T00:00:00","2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-14T00:00:00","2023-01-15T00:00:00","2023-01-16T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-21T00:00:00","2023-01-22T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-26T00:00:00","2023-01-27T00:00:00","2023-01-28T00:00:00","2023-01-29T00:00:00","2023-01-30T00:00:00","2023-01-31T00:00:00","2023-02-01T00:00:00","2023-02-02T00:00:00","2023-02-03T00:00:00","2023-02-04T00:00:00","2023-02-05T00:00:00","2023-02-06T00:00:00","2023-02-07T00:00:00","2023-02-08T00:00:00","2023-02-09T00:00:00","2023-02-10T00:00:00","2023-02-11T00:00:00","2023-02-12T00:00:00","2023-02-13T00:00:00","2023-02-14T00:00:00","2023-02-15T00:00:00","2023-02-16T00:00:00","2023-02-17T00:00:00","2023-02-18T00:00:00","2023-02-19T00:00:00","2023-02-20T00:00:00","2023-02-21T00:00:00","2023-02-22T00:00:00","2023-02-23T00:00:00","2023-0 ...
